# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# %%
# Reshape the input data
X_train = X_train.reshape((-1, 28 * 28))
X_test = X_test.reshape((-1, 28 * 28))

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(28 * 28,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=10, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 [==============================] - 2s 3ms/step - loss: 0.3775 - accuracy: 0.8942 - val_loss: 0.1958 - val_accuracy: 0.9434
# Epoch 2/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1566 - accuracy: 0.9553 - val_loss: 0.1441 - val_accuracy: 0.9570
# Epoch 3/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1104 - accuracy: 0.9675 - val_loss: 0.1174 - val_accuracy: 0.9652
# Epoch 4/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0853 - accuracy: 0.9745 - val_loss: 0.1048 - val_accuracy: 0.9690
# Epoch 5/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0657 - accuracy: 0.9802 - val_loss: 0.1003 - val_accuracy: 0.9683
# Epoch 6/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0535 - accuracy: 0.9842 - val_loss: 0.0938 - val_accuracy: 0.9735
# Epoch 7/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0428 - accuracy: 0.9871 - val_loss: 0.0975 - val_accuracy: 0.9700
# Epoch 8/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0346 - accuracy: 0.9898 - val_loss: 0.1011 - val_accuracy: 0.9714
# Epoch 9/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0288 - accuracy: 0.9914 - val_loss: 0.1107 - val_accuracy: 0.9685
# Epoch 10/10
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0236 - accuracy: 0.9929 - val_loss: 0.0963 - val_accuracy: 0.9741

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0784 - accuracy: 0.9775
# Test Loss: 0.0783957988023758
# Test Accuracy: 0.9775000214576721

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
